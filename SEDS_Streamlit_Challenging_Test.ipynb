# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("piterfm/paris-2024-olympic-summer-games")

print("Path to dataset files:", path)
# Out:
# Downloading from https://www.kaggle.com/api/v1/datasets/download/piterfm/paris-2024-olympic-summer-games?dataset_version_number=27...
# 100%|█████████████████████████████████████████████████████████| 2.95M/2.95M [00:00<00:00, 3.74MB/s]
# Extracting files...
# Path to dataset files: C:\Users\Administrator\.cache\kagglehub\datasets\piterfm\paris-2024-olympic-summer-games\versions\27
